# %%
from datetime import datetime
import MetaTrader5 as mt5
import pandas as pd
import time  

def market_order(symbol, volume,order_type, **kwargs):
    tick = mt5.symbol_info_tick(symbol)
    order_dict = {'buy':0 ,'sell':1}
    price_dict = {'buy': tick.ask , 'sell': tick.bid}
    request = {
        "action":mt5.TRADE_ACTION_DEAL,
        "symbol":symbol,
        "volume":volume,
        "type":order_dict[order_type],
        "price":price_dict[order_type],
        "deviation":DEVIATION,
        "magic":100,
        "Comment":"python market order",
        "type_time":mt5.ORDER_TIME_GTC,
        "type_filling":mt5.ORDER_FILLING_IOC
    }
     # Set stop loss and take profit if provided
    # if stop_loss is not None:
    #     request["sl"] = stop_loss  # Stop loss level
    # if take_profit is not None:
    #     request["tp"] = take_profit  # Take profit level
    order_result = mt5.order_send(request)
    print(order_result)

    return order_result


def signal(symbol,time_frame,sma_period):
    bars = mt5.copy_rates_from_pos(symbol,time_frame,1,sma_period)
    bars_df = pd.DataFrame(bars)

    last_close = bars_df.iloc[-1].close
    sma = bars_df.close.mean()

    direction = 'flat'
    if last_close > sma :
        direction = 'buy'
    elif last_close < sma :
        direction = 'sell'

    return last_close,sma,direction

def close_order(ticket):
    positions = mt5.positions_get()

    for pos in positions:
        tick = mt5.symbol_info_tick(pos.symbol)
        type_dict={0: 1,1: 0}
        price_dict = {0 : tick.ask ,1 : tick.bid}

        if pos.ticket == ticket :
            request = {
                "action":mt5.TRADE_ACTION_DEAL,
                "symbol":pos.symbol,
                "volume":pos.volume,
                "type":type_dict[pos.type],
                "price":price_dict[pos.type],
                "deviation":DEVIATION,
                "magic":100,
                "Comment":"python close order",
                "type_time":mt5.ORDER_TIME_GTC,
                "type_filling":mt5.ORDER_FILLING_IOC
            }
            order_result = mt5.order_send(request)
            return order_result
        else:
            return 'Order does not exist'

def get_exposure(symbol):
    positions = mt5.positions_get(symbol = symbol)
    if positions:
        pos_df = pd.DataFrame(positions, columns = positions[0]._asdict().keys())
        exposure = pos_df['volume'].sum()

        return exposure
if __name__ == '__main__':

        SYMBOL = 'GBPUSD'
        VOLUME = 0.70
        TIMEFRAME = mt5.TIMEFRAME_M1
        SMA_PERIOD = 10
        DEVIATION = 20

        mt5.initialize()

        while True :
             exposure = get_exposure(SYMBOL)

             last_close ,sma,direction = signal(SYMBOL,TIMEFRAME,SMA_PERIOD)

             if direction == 'buy':
                  for pos in mt5.positions_get():
                    if pos.type == 1:
                        close_order(pos.ticket)

                    if not mt5.positions_get():
                        market_order(SYMBOL,VOLUME,direction)
             elif direction == 'sell':
                    # Get all positions
                    positions = mt5.positions_get()

                    # Filter positions that match your criteria (symbol, volume, and direction)
                    filtered_positions = [pos for pos in positions if pos.symbol == SYMBOL and pos.volume == VOLUME and pos.type == 0]

                    # Close each filtered position
                    for pos in filtered_positions:
                        close_order(pos.ticket)

            #  elif direction == 'sell':
            #      for pos in mt5.positions_get(SYMBOL,VOLUME,direction):
            #          if pos.type == 0 :
            #              close_order(pos.ticket)

                    
                    if not mt5.positions_get(SYMBOL,VOLUME,direction):
                        market_order(SYMBOL,VOLUME,direction)

                
             print('time:' , datetime.now())
             print('exposure:',exposure)
             print('last_close', last_close)
             print('sma: ',sma)
             print('signal:', direction)
             print('--------------\n')
             time.sleep(1)
# Out:
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.
stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:18.385143
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22078, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:19.387591
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:20.390680
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:21.393965
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.2208, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:22.398029
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:23.403589
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:24.406907
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:25.413788
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22082, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:26.416747
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22082, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:27.420778
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22075, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:28.422964
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22075, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:29.428179
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22076, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:30.430623
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22075, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:31.433511
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22075, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:32.441401
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22076, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:33.452552
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22078, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:34.599725
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:35.602137
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22081, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:36.607077
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22078, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:37.612096
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22076, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:38.617354
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22076, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:39.619557
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:40.622820
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:41.630017
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:42.633214
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:43.638206
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:44.642664
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:45.645422
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:46.648593
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22075, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:47.652886
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='GBPUSD', volume=0.7, price=1.22077, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-25 13:12:48.655708
# exposure: None
# last_close 1.22072
# sma:  1.221288
# signal: sell
# --------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# g:\Forex dev\jpyclone.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/g%3A/Forex%20dev/jpyclone.ipynb#W0sZmlsZQ%3D%3D?line=127'>128</a> print('signal:', direction)
#     <a href='vscode-notebook-cell:/g%3A/Forex%20dev/jpyclone.ipynb#W0sZmlsZQ%3D%3D?line=128'>129</a> print('--------------\n')
# --> <a href='vscode-notebook-cell:/g%3A/Forex%20dev/jpyclone.ipynb#W0sZmlsZQ%3D%3D?line=129'>130</a> time.sleep(1)
#
# KeyboardInterrupt:
