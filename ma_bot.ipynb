# %%
import pandas as pd
from datetime import datetime
import MetaTrader5 as mt5
import time

# %%
def market_order(symbol, volume,order_type, stop_loss=None, take_profit=None, **kwargs):
    tick = mt5.symbol_info_tick(symbol)
    order_dict = {'buy':0 ,'sell':1}
    price_dict = {'buy': tick.ask , 'sell': tick.bid}
    request = {
        "action":mt5.TRADE_ACTION_DEAL,
        "symbol":symbol,
        "volume":volume,
        "type":order_dict[order_type],
        "price":price_dict[order_type],
        "deviation":DEVIATION,
        "magic":100,
        "Comment":"python market order",
        "type_time":mt5.ORDER_TIME_GTC,
        "type_filling":mt5.ORDER_FILLING_IOC
    }
     # Set stop loss and take profit if provided
    if stop_loss is not None:
        request["sl"] = stop_loss  # Stop loss level
    if take_profit is not None:
        request["tp"] = take_profit  # Take profit level
    order_result = mt5.order_send(request)
    print(order_result)

    return order_result


def signal(symbol,time_frame,sma_period):
    bars = mt5.copy_rates_from_pos(symbol,time_frame,1,sma_period)
    bars_df = pd.DataFrame(bars)

    last_close = bars_df.iloc[-1].close
    sma = bars_df.close.mean()

    direction = 'flat'
    if last_close > sma :
        direction = 'buy'
    elif last_close < sma :
        direction = 'sell'

    return last_close,sma,direction

# %%
def close_order(ticket):
    positions = mt5.positions_get()

    for pos in positions:
        tick = mt5.symbol_info_tick(pos.symbol)
        type_dict={0: 1,1: 0}
        price_dict = {0 : tick.ask ,1 : tick.bid}

        if pos.ticket == ticket :
            request = {
                "action":mt5.TRADE_ACTION_DEAL,
                "symbol":pos.symbol,
                "volume":pos.volume,
                "type":type_dict[pos.type],
                "price":price_dict[pos.type],
                "deviation":DEVIATION,
                "magic":100,
                "Comment":"python close order",
                "type_time":mt5.ORDER_TIME_GTC,
                "type_filling":mt5.ORDER_FILLING_IOC
            }
            order_result = mt5.order_send(request)
            print(order_result)
            return order_result
        else:
            return 'Order does not exist'

def get_exposure(symbol):
    positions = mt5.positions_get(symbol = symbol)
    if positions:
        pos_df = pd.DataFrame(positions, columns = positions[0]._asdict().keys())
        exposure = pos_df['volume'].sum()

        return exposure
if __name__ == '__main__':

        SYMBOL = 'EURUSD'
        VOLUME = 1.0
        TIMEFRAME = mt5.TIMEFRAME_M1
        SMA_PERIOD = 10
        DEVIATION = 20

        mt5.initialize()

        while True :
             exposure = get_exposure(SYMBOL)

             last_close ,sma,direction = signal(SYMBOL,TIMEFRAME,SMA_PERIOD)

             if direction == 'buy':
                  for pos in mt5.positions_get():
                    if pos.type == 1:
                        close_order(pos.ticket)

                    if not mt5.positions_get():
                        market_order(SYMBOL,VOLUME,direction, stop_loss=1.1, take_profit=1.5)
             elif direction == 'sell':
                    # Get all positions
                    positions = mt5.positions_get()

                    # Filter positions that match your criteria (symbol, volume, and direction)
                    filtered_positions = [pos for pos in positions if pos.symbol == SYMBOL and pos.volume == VOLUME and pos.type == 0]

                    # Close each filtered position
                    for pos in filtered_positions:
                        close_order(pos.ticket)

            #  elif direction == 'sell':
            #      for pos in mt5.positions_get(SYMBOL,VOLUME,direction):
            #          if pos.type == 0 :
            #              close_order(pos.ticket)

                    
                    if not mt5.positions_get(SYMBOL,VOLUME,direction):
                        market_order(SYMBOL,VOLUME,direction)

                
             print('time:' , datetime.now())
             print('exposure:',exposure)
             print('last_close', last_close)
             print('sma: ',sma)
             print('signal:', direction)
             print('--------------\n')
             time.sleep(1)
# Out:
# OrderSendResult(retcode=10004, deal=0, order=0, volume=0.0, price=0.0, bid=1.06558, ask=1.06558, comment='Requote', request_id=3305722494, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06559, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:40.570007
# exposure: None
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925391873, order=1950507965, volume=1.0, price=1.06558, bid=1.06558, ask=1.06558, comment='Request executed', request_id=3305722495, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06558, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:41.747837
# exposure: None
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925391993, order=1950508086, volume=1.0, price=1.06559, bid=1.06559, ask=1.06559, comment='Request executed', request_id=3305722496, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06559, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:42.930082
# exposure: 1.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925392027, order=1950508121, volume=1.0, price=1.0656, bid=1.0656, ask=1.0656, comment='Request executed', request_id=3305722497, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:44.100554
# exposure: 2.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925392059, order=1950508153, volume=1.0, price=1.0656, bid=1.0656, ask=1.0656, comment='Request executed', request_id=3305722498, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:45.281842
# exposure: 3.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925392103, order=1950508197, volume=1.0, price=1.0656, bid=1.0656, ask=1.0656, comment='Request executed', request_id=3305722499, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:46.474046
# exposure: 4.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925392157, order=1950508251, volume=1.0, price=1.0656, bid=1.0656, ask=1.0656, comment='Request executed', request_id=3305722500, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:47.658916
# exposure: 5.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925392204, order=1950508299, volume=1.0, price=1.0656, bid=1.0656, ask=1.0656, comment='Request executed', request_id=3305722501, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:48.827879
# exposure: 6.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10009, deal=1925392254, order=1950508350, volume=1.0, price=1.0656, bid=1.0656, ask=1.0656, comment='Request executed', request_id=3305722502, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:50.069024
# exposure: 7.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:51.080727
# exposure: 8.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:15:52.086194
# exposure: 8.0
# last_close 1.06561
# sma:  1.065629
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0656, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08
stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:16:59.834856
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:00.844337
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:01.853603
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0654, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:02.861222
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:03.872915
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:04.881069
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:05.892921
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:06.900668
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:07.912272
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:08.917566
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:09.925720
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:10.936524
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:11.949731
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:12.959041
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:13.968089
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06541, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:14.976184
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06539, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:15.980039
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0654, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:16.989102
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0654, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:17:17.997241
# exposure: 9.0
# last_close 1.06541
# sma:  1.0655569999999999
# signal: sell
# --------------
#
# ...
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06568, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:21.835853
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06568, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:22.844357
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06568, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:23.851531
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06567, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:24.859024
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:25.865779
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:26.882935
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:27.899397
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:28.908238
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:29.924829
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:30.943682
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06566, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:31.951675
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06566, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:32.969491
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:33.978381
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:34.989601
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06564, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:36.009374
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06563, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:37.016269
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06563, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:38.034688
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06562, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:39.042072
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06562, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:40.050966
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06559, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:41.067680
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06559, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:42.083822
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06559, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:43.100850
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:44.115535
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:45.124108
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:46.130045
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:47.137275
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:48.146789
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:49.154911
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:50.163605
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:51.171603
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
#
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06549, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-22 08:20:52.180158
# exposure: 18.0
# last_close 1.06561
# sma:  1.0655240000000001
# signal: buy
# --------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# g:\Forex dev\ma_bot.ipynb Cell 3 line 8
#      <a href='vscode-notebook-cell:/g%3A/Forex%20dev/ma_bot.ipynb#W2sZmlsZQ%3D%3D?line=81'>82</a> print('signal:', direction)
#      <a href='vscode-notebook-cell:/g%3A/Forex%20dev/ma_bot.ipynb#W2sZmlsZQ%3D%3D?line=82'>83</a> print('--------------\n')
# ---> <a href='vscode-notebook-cell:/g%3A/Forex%20dev/ma_bot.ipynb#W2sZmlsZQ%3D%3D?line=83'>84</a> time.sleep(1)
#
# KeyboardInterrupt:

# %%
# def close_all_positions():
positions = mt5.positions_get()

for pos in positions:
    close_order(pos.ticket)
# Out:
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06545, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
