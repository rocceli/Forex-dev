# %%
import pandas as pd
from datetime import datetime
import MetaTrader5 as mt5
import time

# %%
def market_order(symbol, volume,order_type, **kwargs):
    tick = mt5.symbol_info_tick(symbol)
    order_dict = {'buy':0 ,'sell':1}
    price_dict = {'buy': tick.ask , 'sell': tick.bid}
    request = {
        "action":mt5.TRADE_ACTION_DEAL,
        "symbol":symbol,
        "volume":volume,
        "type":order_dict[order_type],
        "price":price_dict[order_type],
        "deviation":DEVIATION,
        "magic":100,
        "Comment":"python market order",
        "type_time":mt5.ORDER_TIME_GTC,
        "type_filling":mt5.ORDER_FILLING_IOC
    }
     # Set stop loss and take profit if provided
    # if stop_loss is not None:
    #     request["sl"] = stop_loss  # Stop loss level
    # if take_profit is not None:
    #     request["tp"] = take_profit  # Take profit level
    order_result = mt5.order_send(request)
    print(order_result)

    return order_result


def signal(symbol,time_frame,sma_period):
    bars = mt5.copy_rates_from_pos(symbol,time_frame,1,sma_period)
    bars_df = pd.DataFrame(bars)

    last_close = bars_df.iloc[-1].close
    sma = bars_df.close.mean()

    direction = 'flat'
    if last_close > sma :
        direction = 'buy'
    elif last_close < sma :
        direction = 'sell'

    return last_close,sma,direction

# %%
def close_order(ticket):
    positions = mt5.positions_get()

    for pos in positions:
        tick = mt5.symbol_info_tick(pos.symbol)
        type_dict={0: 1,1: 0}
        price_dict = {0 : tick.ask ,1 : tick.bid}

        if pos.ticket == ticket :
            request = {
                "action":mt5.TRADE_ACTION_DEAL,
                "symbol":pos.symbol,
                "volume":pos.volume,
                "type":type_dict[pos.type],
                "price":price_dict[pos.type],
                "deviation":DEVIATION,
                "magic":100,
                "Comment":"python close order",
                "type_time":mt5.ORDER_TIME_GTC,
                "type_filling":mt5.ORDER_FILLING_IOC
            }
            order_result = mt5.order_send(request)
            return order_result
        else:
            return 'Order does not exist'

def get_exposure(symbol):
    positions = mt5.positions_get(symbol = symbol)
    if positions:
        pos_df = pd.DataFrame(positions, columns = positions[0]._asdict().keys())
        exposure = pos_df['volume'].sum()

        return exposure
if __name__ == '__main__':

        SYMBOL = 'EURUSD'
        VOLUME = 1.0
        TIMEFRAME = mt5.TIMEFRAME_M1
        SMA_PERIOD = 10
        DEVIATION = 20

        mt5.initialize()

        while True :
             exposure = get_exposure(SYMBOL)

             last_close ,sma,direction = signal(SYMBOL,TIMEFRAME,SMA_PERIOD)

             if direction == 'buy':
                  for pos in mt5.positions_get():
                    total_profit = sum(position.profit for position in positions)
                    print(f"Total Profit from Open Positions: {total_profit}")
                    if total_profit < -50:
                        for pos in positions:
                            close_order(pos.ticket)
                    if pos.type == 1:
                        close_order(pos.ticket)


                    if not mt5.positions_get():
                        market_order(SYMBOL,VOLUME,direction)
             elif direction == 'sell':
                    # Get all positions
                    positions = mt5.positions_get()
                    total_profit = sum(position.profit for position in positions)
        
                    print(f"Total Profit from Open Positions: {total_profit}")
                    if total_profit > -50:
                        for pos in positions:
                            close_order(pos.ticket)

                    # Filter positions that match your criteria (symbol, volume, and direction)
                    filtered_positions = [pos for pos in positions if pos.symbol == SYMBOL and pos.volume == VOLUME and pos.type == 0]

                    # Close each filtered position
                    for pos in filtered_positions:
                        close_order(pos.ticket)

            #  elif direction == 'sell':
            #      for pos in mt5.positions_get(SYMBOL,VOLUME,direction):
            #          if pos.type == 0 :
            #              close_order(pos.ticket)

                    
                    if not mt5.positions_get(SYMBOL,VOLUME,direction):
                        market_order(SYMBOL,VOLUME,direction)
                
            
             print('time:' , datetime.now())
             print('exposure:',exposure)
             print('last_close', last_close)
             print('sma: ',sma)
             print('signal:', direction)
             print('--------------\n')
             time.sleep(1)
# Out:
# Total Profit from Open Positions: 0
# OrderSendResult(retcode=10009, deal=1933441815, order=1958577550, volume=1.0, price=1.05977, bid=1.05977, ask=1.05977, comment='Request executed', request_id=4272335800, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05977, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:47.009900
# exposure: None
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: 1.0
# OrderSendResult(retcode=10009, deal=1933442051, order=1958577788, volume=1.0, price=1.05976, bid=1.05976, ask=1.05976, comment='Request executed', request_id=4272335802, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05976, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:49.030941
# exposure: 1.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -1.0
# OrderSendResult(retcode=10009, deal=1933442152, order=1958577893, volume=1.0, price=1.05974, bid=1.05974, ask=1.05974, comment='Request executed', request_id=4272335804, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05974, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:50.411466
# exposure: 3.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: 1.0
# OrderSendResult(retcode=10009, deal=1933442295, order=1958578103, volume=1.0, price=1.05974, bid=1.05974, ask=1.05974, comment='Request executed', request_id=4272335806, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05974, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:51.808509
# exposure: 4.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -4.0
# OrderSendResult(retcode=10009, deal=1933442409, order=1958578217, volume=1.0, price=1.05973, bid=1.05973, ask=1.05975, comment='Request executed', request_id=4272335807, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05973, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:52.999274
# exposure: 6.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -6.0
# OrderSendResult(retcode=10009, deal=1933442542, order=1958578425, volume=1.0, price=1.0597, bid=1.0597, ask=1.05972, comment='Request executed', request_id=4272335808, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05973, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:54.217899
# exposure: 7.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: 3.0
# OrderSendResult(retcode=10009, deal=1933442674, order=1958578611, volume=1.0, price=1.0597, bid=1.0597, ask=1.05972, comment='Request executed', request_id=4272335815, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0597, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:55.405382
# exposure: 4.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -2.0
# OrderSendResult(retcode=10009, deal=1933442795, order=1958578733, volume=1.0, price=1.0597, bid=1.0597, ask=1.05972, comment='Request executed', request_id=4272335816, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0597, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:56.609401
# exposure: 1.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -10.0
# OrderSendResult(retcode=10009, deal=1933443029, order=1958578899, volume=1.0, price=1.05975, bid=1.05975, ask=1.05977, comment='Request executed', request_id=4272335818, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05975, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:57.995501
# exposure: 2.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -16.0
# OrderSendResult(retcode=10009, deal=1933443201, order=1958579071, volume=1.0, price=1.05975, bid=1.05975, ask=1.05977, comment='Request executed', request_id=4272335820, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05975, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:14:59.364530
# exposure: 4.0
# last_close 1.05953
# sma:  1.059986
# signal: sell
# --------------
#
# Total Profit from Open Positions: -14.0
# OrderSendResult(retcode=10009, deal=1933443305, order=1958579178, volume=1.0, price=1.05973, bid=1.05973, ask=1.05975, comment='Request executed', request_id=4272335821, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05973, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:00.547425
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -21.0
# OrderSendResult(retcode=10009, deal=1933443393, order=1958579285, volume=1.0, price=1.05973, bid=1.05972, ask=1.05974, comment='Request executed', request_id=4272335822, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05973, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:01.799943
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -10.0
# OrderSendResult(retcode=10009, deal=1933443609, order=1958579485, volume=1.0, price=1.05971, bid=1.05971, ask=1.05973, comment='Request executed', request_id=4272335823, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05971, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:02.989676
# exposure: 8.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -12.0
# OrderSendResult(retcode=10009, deal=1933443740, order=1958579676, volume=1.0, price=1.05971, bid=1.0597, ask=1.0597, comment='Request executed', request_id=4272335824, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05971, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:04.200837
# exposure: 9.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 18.0
# OrderSendResult(retcode=10009, deal=1933443977, order=1958579814, volume=1.0, price=1.05968, bid=1.05969, ask=1.05969, comment='Request executed', request_id=4272335833, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05968, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:05.411202
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -1.0
# OrderSendResult(retcode=10009, deal=1933444076, order=1958579923, volume=1.0, price=1.0596700000000001, bid=1.0596700000000001, ask=1.05969, comment='Request executed', request_id=4272335834, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0596700000000001, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:06.588199
# exposure: 1.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -3.0
# OrderSendResult(retcode=10009, deal=1933444177, order=1958580027, volume=1.0, price=1.0596700000000001, bid=1.0596700000000001, ask=1.05969, comment='Request executed', request_id=4272335835, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0596700000000001, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:08.108977
# exposure: 2.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -5.0
# OrderSendResult(retcode=10009, deal=1933444278, order=1958580135, volume=1.0, price=1.0596700000000001, bid=1.0596700000000001, ask=1.05969, comment='Request executed', request_id=4272335836, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0596700000000001, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:09.376611
# exposure: 3.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 1.0
# OrderSendResult(retcode=10009, deal=1933444398, order=1958580264, volume=1.0, price=1.05965, bid=1.05965, ask=1.0596700000000001, comment='Request executed', request_id=4272335837, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05965, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:10.552121
# exposure: 4.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -1.0
# OrderSendResult(retcode=10009, deal=1933444538, order=1958580411, volume=1.0, price=1.05965, bid=1.05965, ask=1.0596700000000001, comment='Request executed', request_id=4272335838, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05965, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:11.749915
# exposure: 5.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -3.0
# OrderSendResult(retcode=10009, deal=1933444644, order=1958580515, volume=1.0, price=1.05965, bid=1.05965, ask=1.0596700000000001, comment='Request executed', request_id=4272335839, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05965, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:12.992412
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -26.0
# OrderSendResult(retcode=10009, deal=1933444719, order=1958580590, volume=1.0, price=1.05968, bid=1.05968, ask=1.0597, comment='Request executed', request_id=4272335840, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05968, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:14.198947
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 28.0
# OrderSendResult(retcode=10009, deal=1933444825, order=1958580695, volume=1.0, price=1.05961, bid=1.05961, ask=1.05963, comment='Request executed', request_id=4272335841, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05961, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:15.421934
# exposure: 8.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 3.0
# OrderSendResult(retcode=10009, deal=1933444922, order=1958580791, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335851, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:16.633990
# exposure: 1.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 3.0
# OrderSendResult(retcode=10009, deal=1933444992, order=1958580862, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335852, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:17.821015
# exposure: 2.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 13.0
# OrderSendResult(retcode=10009, deal=1933445145, order=1958581011, volume=1.0, price=1.05953, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335854, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05953, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:19.237197
# exposure: 3.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 11.0
# OrderSendResult(retcode=10009, deal=1933445219, order=1958581086, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335855, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:20.430195
# exposure: 5.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 13.0
# OrderSendResult(retcode=10009, deal=1933445351, order=1958581219, volume=1.0, price=1.0594999999999999, bid=1.0594999999999999, ask=1.05952, comment='Request executed', request_id=4272335856, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0594999999999999, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:21.620102
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 6.0
# OrderSendResult(retcode=10009, deal=1933445487, order=1958581359, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335857, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:22.847426
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 4.0
# OrderSendResult(retcode=10009, deal=1933445622, order=1958581497, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335858, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:24.066147
# exposure: 8.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -4.0
# OrderSendResult(retcode=10009, deal=1933445747, order=1958581617, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335867, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:25.620151
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -6.0
# OrderSendResult(retcode=10009, deal=1933446003, order=1958581872, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335868, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:26.831425
# exposure: 1.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -8.0
# OrderSendResult(retcode=10009, deal=1933446075, order=1958582094, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335869, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:28.155935
# exposure: 2.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -13.0
# OrderSendResult(retcode=10009, deal=1933446294, order=1958582189, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335870, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:29.352282
# exposure: 3.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -11.0
# OrderSendResult(retcode=10009, deal=1933446571, order=1958582392, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335871, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:30.569294
# exposure: 4.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -18.0
# OrderSendResult(retcode=10009, deal=1933446750, order=1958582573, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335872, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:31.765117
# exposure: 5.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -20.0
# OrderSendResult(retcode=10009, deal=1933446797, order=1958582623, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335873, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:32.971080
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -36.0
# OrderSendResult(retcode=10009, deal=1933446874, order=1958582702, volume=1.0, price=1.0596, bid=1.0596, ask=1.0596, comment='Request executed', request_id=4272335875, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0596, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:34.536687
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -3.0
# OrderSendResult(retcode=10009, deal=1933446955, order=1958582775, volume=1.0, price=1.05953, bid=1.05954, ask=1.05956, comment='Request executed', request_id=4272335877, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05953, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:35.975480
# exposure: 9.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 0
# OrderSendResult(retcode=10009, deal=1933447064, order=1958582889, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335887, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:37.188125
# exposure: None
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -2.0
# OrderSendResult(retcode=10009, deal=1933447133, order=1958582957, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335888, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:38.388128
# exposure: 1.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -6.0
# OrderSendResult(retcode=10009, deal=1933447198, order=1958583024, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335889, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:39.590590
# exposure: 2.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -8.0
# OrderSendResult(retcode=10009, deal=1933447261, order=1958583090, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335890, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:40.794348
# exposure: 3.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -10.0
# OrderSendResult(retcode=10009, deal=1933447345, order=1958583176, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335891, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:42.007556
# exposure: 4.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -12.0
# OrderSendResult(retcode=10009, deal=1933447427, order=1958583260, volume=1.0, price=1.05956, bid=1.05956, ask=1.05958, comment='Request executed', request_id=4272335892, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05956, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:43.196081
# exposure: 5.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -8.0
# OrderSendResult(retcode=10009, deal=1933447491, order=1958583325, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335893, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:44.414360
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -10.0
# OrderSendResult(retcode=10009, deal=1933447557, order=1958583421, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335894, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:45.692302
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -12.0
# OrderSendResult(retcode=10009, deal=1933447627, order=1958583491, volume=1.0, price=1.05955, bid=1.05955, ask=1.05957, comment='Request executed', request_id=4272335895, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:46.901554
# exposure: 8.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -14.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:47.906925
# exposure: 9.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 22.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:48.915551
# exposure: 9.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 0
# OrderSendResult(retcode=10009, deal=1933447800, order=1958583664, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335905, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:50.133027
# exposure: None
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -2.0
# OrderSendResult(retcode=10009, deal=1933447891, order=1958583756, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335906, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:51.339675
# exposure: 1.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -4.0
# OrderSendResult(retcode=10009, deal=1933447960, order=1958583825, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335907, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:52.528772
# exposure: 2.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -6.0
# OrderSendResult(retcode=10009, deal=1933448053, order=1958583921, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335908, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:53.730768
# exposure: 3.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -8.0
# OrderSendResult(retcode=10009, deal=1933448134, order=1958584009, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335909, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:54.914679
# exposure: 4.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -10.0
# OrderSendResult(retcode=10009, deal=1933448221, order=1958584095, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335910, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:56.105949
# exposure: 5.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -12.0
# OrderSendResult(retcode=10009, deal=1933448324, order=1958584201, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335911, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:57.308054
# exposure: 6.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -14.0
# OrderSendResult(retcode=10009, deal=1933448384, order=1958584267, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335912, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:58.760543
# exposure: 7.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: -16.0
# OrderSendResult(retcode=10009, deal=1933448516, order=1958584563, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335913, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:15:59.963143
# exposure: 8.0
# last_close 1.05975
# sma:  1.059922
# signal: sell
# --------------
#
# Total Profit from Open Positions: 0.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05949, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:00.969857
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: 0.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05949, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:01.976045
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: 0.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05949, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:02.981847
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: 0
# OrderSendResult(retcode=10009, deal=1933449114, order=1958585044, volume=1.0, price=1.05951, bid=1.05951, ask=1.05953, comment='Request executed', request_id=4272335924, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:04.177619
# exposure: None
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: 2.0
# OrderSendResult(retcode=10009, deal=1933449368, order=1958585253, volume=1.0, price=1.05947, bid=1.05947, ask=1.05949, comment='Request executed', request_id=4272335925, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05947, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:05.365886
# exposure: 1.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -4.0
# OrderSendResult(retcode=10009, deal=1933449419, order=1958585303, volume=1.0, price=1.05949, bid=1.05949, ask=1.05951, comment='Request executed', request_id=4272335926, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05949, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:06.587553
# exposure: 2.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -9.0
# OrderSendResult(retcode=10004, deal=0, order=0, volume=0.0, price=0.0, bid=1.05948, ask=1.0594999999999999, comment='Requote', request_id=4272335927, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0594999999999999, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:07.891624
# exposure: 3.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -3.0
# OrderSendResult(retcode=10009, deal=1933449563, order=1958585452, volume=1.0, price=1.05948, bid=1.05948, ask=1.0594999999999999, comment='Request executed', request_id=4272335928, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05948, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:09.407374
# exposure: 3.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: 1.0
# OrderSendResult(retcode=10009, deal=1933449681, order=1958585572, volume=1.0, price=1.05946, bid=1.05946, ask=1.05948, comment='Request executed', request_id=4272335929, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05946, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:10.629280
# exposure: 4.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -19.0
# OrderSendResult(retcode=10009, deal=1933449759, order=1958585652, volume=1.0, price=1.0594999999999999, bid=1.0594999999999999, ask=1.05952, comment='Request executed', request_id=4272335931, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0594999999999999, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:12.006818
# exposure: 5.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -21.0
# OrderSendResult(retcode=10009, deal=1933449856, order=1958585750, volume=1.0, price=1.05947, bid=1.05947, ask=1.05949, comment='Request executed', request_id=4272335933, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0594999999999999, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:13.405955
# exposure: 6.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -5.0
# OrderSendResult(retcode=10009, deal=1933449944, order=1958585839, volume=1.0, price=1.05947, bid=1.05947, ask=1.05949, comment='Request executed', request_id=4272335934, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05947, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:14.603477
# exposure: 7.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -7.0
# OrderSendResult(retcode=10009, deal=1933450060, order=1958585956, volume=1.0, price=1.05947, bid=1.05947, ask=1.05949, comment='Request executed', request_id=4272335935, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05947, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:16.002282
# exposure: 8.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -18.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05948, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:17.007119
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -9.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05947, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:18.021038
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -9.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05947, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:19.026459
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -27.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05949, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:20.032398
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -45.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:21.038841
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -45.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:22.046830
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -45.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:23.054869
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -45.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:24.061034
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -45.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05951, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:25.066116
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -81.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05955, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:26.070556
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -72.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05954, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:27.074621
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -72.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05954, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:28.079206
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -72.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05954, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:16:29.082983
# exposure: 9.0
# last_close 1.05951
# sma:  1.059849
# signal: sell
# --------------
#
# Total Profit from Open Positions: -45.0
# ...
# time: 2023-09-26 13:32:31.969914
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05907, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:32.981929
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.0590600000000001, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:33.992059
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05909, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:35.003023
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05917, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:36.009380
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05919, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:37.022091
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05919, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:38.029691
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05919, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:39.036042
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05919, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:40.042465
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05916, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:41.048191
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05911, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:42.061833
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05911, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:43.066286
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05912, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:44.071688
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05912, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:45.081686
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05911, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:46.088749
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05911, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:47.094691
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05911, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:48.101990
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05911, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:49.116682
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -435.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05914, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:50.123090
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05915, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:51.129603
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05918, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:52.138798
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -435.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05921, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:53.152651
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -435.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05921, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:54.164900
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05922, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:55.169643
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -435.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05923, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:56.175697
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05924, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:57.180349
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -444.0
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05924, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:58.192848
# exposure: 18.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -261.0
# OrderSendResult(retcode=10009, deal=1933539715, order=1958676295, volume=1.0, price=1.05925, bid=1.05925, ask=1.05925, comment='Request executed', request_id=4272336167, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.05925, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
# time: 2023-09-26 13:32:59.597797
# exposure: 12.0
# last_close 1.05915
# sma:  1.059189
# signal: sell
# --------------
#
# Total Profit from Open Positions: -261.0
# time: 2023-09-26 13:33:00.615404
# exposure: 3.0
# last_close 1.05925
# sma:  1.0591940000000002
# signal: buy
# --------------
#
# time: 2023-09-26 13:33:01.619399
# exposure: None
# last_close 1.05925
# sma:  1.0591940000000002
# signal: buy
# --------------
#
# time: 2023-09-26 13:33:02.623395
# exposure: None
# last_close 1.05925
# sma:  1.0591940000000002
# signal: buy
# --------------
#
# time: 2023-09-26 13:33:03.629298
# exposure: None
# last_close 1.05925
# sma:  1.0591940000000002
# signal: buy
# --------------
#
# time: 2023-09-26 13:33:04.632515
# exposure: None
# last_close 1.05925
# sma:  1.0591940000000002
# signal: buy
# --------------
#
# time: 2023-09-26 13:33:05.634519
# exposure: None
# last_close 1.05925
# sma:  1.0591940000000002
# signal: buy
# --------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# g:\Forex dev\ma_bot.ipynb Cell 3 line 9
#      <a href='vscode-notebook-cell:/g%3A/Forex%20dev/ma_bot.ipynb#W2sZmlsZQ%3D%3D?line=92'>93</a> print('signal:', direction)
#      <a href='vscode-notebook-cell:/g%3A/Forex%20dev/ma_bot.ipynb#W2sZmlsZQ%3D%3D?line=93'>94</a> print('--------------\n')
# ---> <a href='vscode-notebook-cell:/g%3A/Forex%20dev/ma_bot.ipynb#W2sZmlsZQ%3D%3D?line=94'>95</a> time.sleep(1)
#
# KeyboardInterrupt:

# %%
# def close_all_positions():
positions = mt5.positions_get()

for pos in positions:
    close_order(pos.ticket)
# Out:
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=100, order=0, symbol='EURUSD', volume=1.0, price=1.06545, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='', position=0, position_by=0))
